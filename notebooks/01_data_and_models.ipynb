# %% [markdown]
# # G-NeSAI: Data & Models Notebook
#
# This notebook demonstrates data generation, visualization, a tiny training run, and exporting artifacts for publication. It's a smoke-test notebook designed to run on CPU.
